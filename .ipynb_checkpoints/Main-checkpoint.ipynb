# %% [markdown]
# <p><h3>Comparing Airbnb Seattle and Boston Datasets</h3></p>
#
# <p>This notebook is dealing with the Aribnb datasets in Seattle and Boston and trying to provide some insights for business owners on market prices and how to improve customer experiences.</p>
#
# <p>There are three business questions to be answered and compare the both:<br>
#     1. Which factor affects the price most?<br>
#     2. Airbnb markets of Seattle and Boston?<br>
#     3. Which aspects are valued most in terms of customer experience? Is it the same for both?
# </p>

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %matplotlib inline

# %% [markdown]
# <p><h3>Question 1: Which factor affect the price most?</h3></p>
# <p>Here price is the target variable, where we want to predict which factor affects price the most and is it same for both(Seattle and Boston).</p>
#
# <p>There are many columns that will not affect price. Below are the columns that affect the price most.</p>
# <p>1. neighbourhood_cleansed <br>
#    2. property_type <br>
#    3. room_type <br>
#    4. accommodates <br>
#    5. bathrooms <br>
#    6. bedrooms <br>
#    7. beds <br>
#    8. bed_type </p>
#
# <p>As data is not perfect, we'll need to analyze and clean the data. After that building the model and analyze the result. </p>

# %%
# Reading .csv file
seattle_listings = pd.read_csv("seattle/listings.csv")
seattle_listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
seattle_listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
seattle_listings["price"].head()
# Out:
# 0     $85.00
# 1    $150.00
# 2    $975.00
# 3    $100.00
# 4    $450.00
# Name: price, dtype: object

# %%
seattle_listings[["price"]].isna().sum()
seattle_listings.shape
# Out:
# (3818, 92)

# %% [markdown]
# <p><h4>Precleaning the data</h4></p>
# Converting the format and data type of "price" column, and then clean(pre_process) the dataframe.
#
# For numerical variables, NaN value is imputed by the mean. Simply dropping the entire row will remove information that may be useful for our prediction. Because there's no abnormal high value, mean value can be the best one to be imputed.
#
# For categorical variables, we encode them into dummies by removing original columns with data type of "object" and concatenate dummy columns into the dataframe. This dummy columns can help us demonstrate which category in which variable more contributes to the target variable.

# %%
def pre_process(df, X_columns, y_column):
    '''
    INPUT:
    df - the dataframe 
    
    OUTPUT:
    X - cleaned dataframe that containes all variables which may affect target variable
    y - cleaned dataframe of target variable
    
    Split the original dataframe to target variable and others. Clean the data by
    1) Drop the row with NaN target variable
    2) Imputing NaN values for numerical variables
    3) Create dummies for categorical values
    '''
    
    df[y_column].replace("[\$,]", "", regex=True, inplace=True)
    df[y_column] = df[y_column].astype(float)
    
    df = df.dropna(subset=[y_column], axis=0)
    
    y = df[[y_column]]
    
    X = df[]
    
    num_vars = X.select_dtypes(include=["int", "float"]).columns
    
    for col in num_vars:
        X[col].fillna((X[col].mean()), inplace=True)
    
    cat_vars = X.select_dtypes(include=["object"]).columns
    
    for var in cat_vars:
        X = pd.concat([X.drop([var], axis=1), pd.get_dummies(X[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)
    
    return X, y
# Out:
#   File "<ipython-input-6-987ef1f232b9>", line 23
#     X = df[]
#            ^
# SyntaxError: invalid syntax

# %%
X_columns = ["neighbourhood_cleansed", "property_type", "room_type", "accommodates", "bathrooms", "bedrooms", "beds", "bed_type"]
X_seattle, y_seattle = pre_process(seattle_listings, X_columns, "price")
X_seattle.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8eb3f7f4a345> in <module>
#       1 X_columns = ["neighbourhood_cleansed", "property_type", "room_type", "accommodates", "bathrooms", "bedrooms", "beds", "bed_type"]
# ----> 2 X_seattle, y_seattle = pre_process(seattle_listings, X_columns, "price")
#       3 X_seattle.head()
#
# NameError: name 'pre_process' is not defined

# %% [markdown]
# <p><h4>Building model</h4></p>

# %%
#Split into train and test
X_sea_train, X_sea_test, y_sea_train, y_sea_test = train_test_split(X_seattle, y_seattle, test_size = .30, random_state=42) 

lm_model_sea = LinearRegression(normalize=True) # Instantiate
lm_model_sea.fit(X_sea_train, y_sea_train) # Fit
        
#Predict and score the model
y_sea_test_preds = lm_model_sea.predict(X_sea_test) 
"The r-squared score for your model was {} on {} values.".format(r2_score(y_sea_test, y_sea_test_preds), len(y_sea_test))
# Out:
# 'The r-squared score for your model was 0.5893688545040465 on 1146 values.'

# %%
X_sea_train.shape
# Out:
# (2672, 111)

# %%
lm_model_sea.coef_.shape
# Out:
# (1, 111)

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = coefficients
    coefs_df['abs_coefs'] = np.abs(coefficients)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

# %%
coef_sea_df = coef_weights(lm_model_sea.coef_[0], X_sea_train)
coef_sea_df.head(30)
# Out:
#                                               est_int       coefs   abs_coefs
# 91                                 property_type_Boat  152.717881  152.717881
# 35         neighbourhood_cleansed_Industrial District   95.699767   95.699767
# 97                                 property_type_Dorm  -87.769391   87.769391
# 63              neighbourhood_cleansed_Pioneer Square   86.509158   86.509158
# 64                 neighbourhood_cleansed_Portage Bay   81.840475   81.840475
# 76          neighbourhood_cleansed_Southeast Magnolia   80.356239   80.356239
# 61                 neighbourhood_cleansed_Pike-Market   75.776303   75.776303
# 106                             room_type_Shared room  -69.238002   69.238002
# 86                    neighbourhood_cleansed_Westlake   67.706353   67.706353
# 84             neighbourhood_cleansed_West Queen Anne   63.223066   63.223066
# 103                           property_type_Treehouse   51.822068   51.822068
# ...

# %%
loc_vals = seattle_listings["neighbourhood_cleansed"].value_counts()

(loc_vals[0:10]/seattle_listings.shape[0]).plot(kind="bar");
plt.title("Where Seattle Airbnb properties locate");

# %% [markdown]
# <p><h5>Reading Boston data</h5></p>
# After reading, applying same process to this dataset.

# %%
boston_listings = pd.read_csv("boston/listings.csv")
boston_listings.shape
# Out:
# (3585, 95)

# %%
boston_listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...

# %%
X_boston, y_boston = pre_process(boston_listings, X_columns, "price")
X_boston.head()
# Out:
# C:\Users\zrohi\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#    accommodates  bathrooms  bedrooms  beds  neighbourhood_cleansed_Back Bay  \
# 0             4        1.5       2.0   3.0                                0
# 1             2        1.0       1.0   1.0                                0
# 2             2        1.0       1.0   1.0                                0
# 3             4        1.0       1.0   2.0                                0
# 4             2        1.5       1.0   2.0                                0
#
#    neighbourhood_cleansed_Bay Village  neighbourhood_cleansed_Beacon Hill  \
# 0                                   0                                   0
# ...

# %%
#Split into train and test
X_bos_train, X_bos_test, y_bos_train, y_bos_test = train_test_split(X_boston, y_boston, test_size = .30, random_state=42) 

lm_model_bos = LinearRegression(normalize=True) # Instantiate
lm_model_bos.fit(X_bos_train, y_bos_train) # Fit
        
#Predict and score the model
y_bos_test_preds = lm_model_bos.predict(X_bos_test) 
"The r-squared score for your model was {} on {} values.".format(r2_score(y_bos_test, y_bos_test_preds), len(y_bos_test))
# Out:
# 'The r-squared score for your model was 0.2780488434074263 on 1076 values.'

# %%
coef_bos_df = coef_weights(lm_model_bos.coef_[0], X_bos_train)
coef_bos_df.head(30)
# Out:
#                                            est_int       coefs   abs_coefs
# 24  neighbourhood_cleansed_South Boston Waterfront  146.826802  146.826802
# 30                         property_type_Camper/RV -123.218149  123.218149
# 16         neighbourhood_cleansed_Leather District  110.347259  110.347259
# 4                  neighbourhood_cleansed_Back Bay  109.832531  109.832531
# 6               neighbourhood_cleansed_Beacon Hill  103.228922  103.228922
# 5               neighbourhood_cleansed_Bay Village  103.124933  103.124933
# 11                 neighbourhood_cleansed_Downtown   92.796762   92.796762
# 13                   neighbourhood_cleansed_Fenway   83.718319   83.718319
# 25                neighbourhood_cleansed_South End   73.152004   73.152004
# 9                 neighbourhood_cleansed_Chinatown   71.120796   71.120796
# 41                           room_type_Shared room  -69.554764   69.554764
# ...

# %%
loc_vals = boston_listings["neighbourhood_cleansed"].value_counts()

(loc_vals[0:10]/boston_listings.shape[0]).plot(kind="bar");
plt.title("Where Boston Airbnb properties locate");

# %% [markdown]
# <h4>Conclusions</h4>
# <p>In conlusion, the location of the Airbnb property plays the most important role in its pricing , both in Seattle and Boston. Some locations are not ideal for Airbnb business.
#
# We can see from the chart that in Seattle, price drops significantly as compared to Boston.
#
# Property type can also affect the price. Some rare property types like 'Boat' and 'Dorm' in Seattle are top indicators of the pricing, while in Boston it does not have greater effect. Whereas the lack of data may leads to inappropriate judgements on how much the price indicated by property type. In terms of room type, sharing room usually indicates a low price both in Seattle and Boston. The number of bedrooms, beds, bathrooms and bed type is also an indicator, but not as crucial as location and property/room type.</p>

# %%
price_boston = boston_listings['price'].mean()
price_seattle = seattle_listings['price'].mean()

"The average price of Airbnb is ${:.2f} in Boston, and ${:.2f} in Seattle, which is ${:.2f} {} than Boston".format(
    price_boston, price_seattle, abs(price_seattle-price_boston), 'higher' if price_seattle>price_boston else 'lower')
# Out:
# 'The average price of Airbnb is $173.93 in Boston, and $127.98 in Seattle, which is $45.95 lower than Boston'

# %%
review_boston = boston_listings['review_scores_rating'].mean()
review_seattle = seattle_listings['review_scores_rating'].mean()   

"The average review rating of Airbnb is {:.2f} in Boston, and {:.2f} in Seattle.".format(review_boston, review_seattle)
# Out:
# 'The average review rating of Airbnb is 91.92 in Boston, and 94.54 in Seattle.'

# %%
seattle_listings["property_type"].value_counts()
# Out:
# House              1733
# Apartment          1708
# Townhouse           118
# Condominium          91
# Loft                 40
# Bed & Breakfast      37
# Other                22
# Cabin                21
# Camper/RV            13
# Bungalow             13
# Boat                  8
# Tent                  5
# Treehouse             3
# Dorm                  2
# Chalet                2
# Yurt                  1
# Name: property_type, dtype: int64

# %%
boston_listings["property_type"].value_counts()
# Out:
# Apartment          2612
# House               562
# Condominium         231
# Townhouse            54
# Bed & Breakfast      41
# Loft                 39
# Other                17
# Boat                 12
# Villa                 6
# Entire Floor          4
# Dorm                  2
# Guesthouse            1
# Camper/RV             1
# Name: property_type, dtype: int64

# %% [markdown]
# <h4>COnclusion</h4>
# <p>In, general, the average pricing in Boston is higher than Seattle. Whereas average review rating of Seattle is greater than Boston. From this we can say that customer in Seattle is more satisfied compare to Boston.
# </p>

# %%
X_review_cols = ['review_scores_value', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 
                 'review_scores_communication', 'review_scores_location']

# %%
seattle_review = seattle_listings[["review_scores_rating", "review_scores_value", "review_scores_accuracy", 
                                   "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", 
                                   "review_scores_location"]]
seattle_review.head()
# Out:
#    review_scores_rating  review_scores_value  review_scores_accuracy  \
# 0                  95.0                 10.0                    10.0
# 1                  96.0                 10.0                    10.0
# 2                  97.0                 10.0                    10.0
# 3                   NaN                  NaN                     NaN
# 4                  92.0                  9.0                     9.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                        NaN                    NaN
# 4                        9.0                   10.0
#
#    review_scores_communication  review_scores_location
# 0                         10.0                     9.0
# 1                         10.0                    10.0
# 2                         10.0                    10.0
# ...

# %%
X_sea_rev, y_sea_rev = pre_process(seattle_review, X_review_cols, "review_scores_rating")
X_sea_rev.head()
# Out:
# C:\Users\zrohi\Anaconda3\lib\site-packages\pandas\core\generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\zrohi\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\zrohi\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
y_sea_rev.head()
# Out:
#    review_scores_rating
# 0                  95.0
# 1                  96.0
# 2                  97.0
# 4                  92.0
# 5                  95.0

# %%
#Split into train and test
X_rev_sea_train, X_rev_sea_test, y_rev_sea_train, y_rev_sea_test = train_test_split(X_sea_rev, y_sea_rev, test_size = .30, random_state=42) 

lm_model_sea_rev = LinearRegression(normalize=True) # Instantiate
lm_model_sea_rev.fit(X_rev_sea_train, y_rev_sea_train) #Fit
        
#Predict and score the model
y_sea_rev_test_preds = lm_model_sea_rev.predict(X_rev_sea_test) 
"The r-squared score for your model was {} on {} values.".format(r2_score(y_rev_sea_test, y_sea_rev_test_preds), len(y_rev_sea_test))
# Out:
# 'The r-squared score for your model was 0.6485531047095809 on 952 values.'

# %%
coef_sea_rev = coef_weights(lm_model_sea_rev.coef_[0], X_rev_sea_train)
coef_sea_rev
# Out:
#                        est_int     coefs  abs_coefs
# 0          review_scores_value  3.058346   3.058346
# 2    review_scores_cleanliness  2.352576   2.352576
# 1       review_scores_accuracy  1.526999   1.526999
# 3        review_scores_checkin  1.294785   1.294785
# 4  review_scores_communication  1.267077   1.267077
# 5       review_scores_location  0.533938   0.533938

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%".format(pct)

# %%
fig, ax = plt.subplots(figsize=(16, 8), subplot_kw=dict(aspect="equal"))
patches, texts, autotexts = ax.pie(coef_sea_rev["abs_coefs"], autopct=lambda pct: func(pct, coef_sea_rev["abs_coefs"]), 
                                   textprops=dict(color="w"))

ax.legend(patches, coef_sea_rev["est_int"], loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.setp(autotexts, size=16, weight="bold")
plt.show()

# %%
boston_review = boston_listings[["review_scores_rating", "review_scores_value", "review_scores_accuracy", 
                                   "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", 
                                   "review_scores_location"]]
boston_review.head()
# Out:
#    review_scores_rating  review_scores_value  review_scores_accuracy  \
# 0                   NaN                  NaN                     NaN
# 1                  94.0                  9.0                    10.0
# 2                  98.0                 10.0                    10.0
# 3                 100.0                 10.0                    10.0
# 4                  99.0                 10.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        9.0                   10.0
# 2                        9.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location
# 0                          NaN                     NaN
# 1                         10.0                     9.0
# 2                         10.0                     9.0
# ...

# %%
X_bos_rev, y_bos_rev = pre_process(boston_review, X_review_cols, "review_scores_rating")
X_bos_rev.head()
# Out:
# C:\Users\zrohi\Anaconda3\lib\site-packages\pandas\core\generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\zrohi\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\zrohi\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
y_bos_rev.head()
# Out:
#    review_scores_rating
# 1                  94.0
# 2                  98.0
# 3                 100.0
# 4                  99.0
# 5                 100.0

# %%
#Split into train and test
X_bos_rev_train, X_bos_rev_test, y_bos_rev_train, y_bos_rev_test = train_test_split(X_bos_rev, y_bos_rev, test_size = .30, random_state=42) 

lm_model_bos_rev = LinearRegression(normalize=True) # Instantiate
lm_model_bos_rev.fit(X_bos_rev_train, y_bos_rev_train) # Fit
        
#Predict and score the model
y_bos_rev_test_preds = lm_model_bos_rev.predict(X_bos_rev_test) 
"The r-squared score for your model was {} on {} values.".format(r2_score(y_bos_rev_test, y_bos_rev_test_preds), len(y_bos_rev_test))
# Out:
# 'The r-squared score for your model was 0.7108256133047017 on 832 values.'

# %%
coef_bos_rev = coef_weights(lm_model_bos_rev.coef_[0], X_bos_rev_train)
coef_bos_rev
# Out:
#                        est_int     coefs  abs_coefs
# 0          review_scores_value  2.928913   2.928913
# 2    review_scores_cleanliness  2.711272   2.711272
# 3        review_scores_checkin  1.630898   1.630898
# 4  review_scores_communication  1.622233   1.622233
# 1       review_scores_accuracy  1.431142   1.431142
# 5       review_scores_location  0.650595   0.650595

# %%
fig, ax = plt.subplots(figsize=(16, 8), subplot_kw=dict(aspect="equal"))
patches, texts, autotexts = ax.pie(coef_bos_rev["abs_coefs"], autopct=lambda pct: func(pct, coef_bos_rev["abs_coefs"]), 
                                   textprops=dict(color="w"))

ax.legend(patches, coef_bos_rev["est_int"], loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.setp(autotexts, size=16, weight="bold")
plt.show()

# %% [markdown]
# <h4>Conclusion</h4>
# <p>As shown in the pie charts above, the value and cleanliness are the top two factors that the business owner should consider to improve their customer experience, both in Seattle and Boston. In contrast to price prediction, location is the least factor that affects the customer experience. We can also see that even though average price in Boston is higher, customer gives high review value. From this we might say that Boston cost of living is higher than Seattle.
# </p>
